# %%
import svgutils.transform as sg
from IPython.display import SVG

width = 14
height = 3.3
fig = sg.SVGFigure(width=f"{width}cm", height=f"{height}cm")


fig1 = sg.fromfile("fig_ordering_base_handcrafted.svg")
plot1 = fig1.getroot()

plot2 = sg.fromfile("fig_ordering_base_sbibm.svg")
plot2 = plot2.getroot()

plot3 = sg.fromfile("legend_only.svg")
plot3 = plot3.getroot()

txt1 = sg.TextElement(40, 15, "Simple nonlin.", size=9, weight="None", font="Arial")
txt2 = sg.TextElement(115, 15, "Mixed dis.", size=9, weight="None", font="Arial")
txt3 = sg.TextElement(200, 15, "Two Moons", size=9, weight="None", font="Arial")
txt4 = sg.TextElement(280, 15, "SLCP", size=9, weight="None", font="Arial")
txt5 = sg.TextElement(320, 15, "Bernoulli GLM", size=9, weight="None", font="Arial")
txt6 = sg.TextElement(405, 15, "SIR", size=9, weight="None", font="Arial")
txt7 = sg.TextElement(450, 15, "Lotka Volterra", size=9, weight="None", font="Arial")
plot1.moveto(0, 10, scale=1.0)
plot2.moveto(170, 10, scale=1.0)
plot3.moveto(170, 90, scale=1.0)

fig.append([plot1, plot2, plot3])
fig.append([txt1, txt2, txt3, txt4, txt5, txt6, txt7])

fig.save("fig_ordering.svg")

svg = SVG("fig_ordering.svg")
svg
