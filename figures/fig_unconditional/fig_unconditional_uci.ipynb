# %%
import sys

import svgutils.transform as sg
from IPython.display import SVG

width = 14
height = 4.5
fig = sg.SVGFigure(width=f"{width}cm", height=f"{height}cm")

print(width * 37.7952755906)
print(height * 37.7952755906)

plot1 = sg.fromfile("uci_results.svg")
plot1 = plot1.getroot()
plot1.moveto(7, 0, scale=1.0)

fig.append([plot1])

fig.save("fig_unconditional_uci.svg")

svg = SVG("fig_unconditional_uci.svg")
svg
# Out:
# 529.1338582684
# 170.0787401577
