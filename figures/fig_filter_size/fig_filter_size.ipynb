# %%
import svgutils.transform as sg
from IPython.display import SVG

width = 14
height = 3.05
fig = sg.SVGFigure(width=f"{width}cm", height=f"{height}cm")

print(width * 37.7952755906)
print(height * 37.7952755906)

plot1 = sg.fromfile("vary_filter_sizes.svg")
plot1 = plot1.getroot()
plot1.moveto(13, 0, scale=1.0)

fig.append([plot1])

fig.save("fig_filter_size.svg")

svg = SVG("fig_filter_size.svg")
svg
# Out:
# 529.1338582684
# 115.27559055133
