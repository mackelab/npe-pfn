# %%
import svgutils.transform as sg
from IPython.display import SVG

width = 14
height = 2.8
fig = sg.SVGFigure(width=f"{width}cm", height=f"{height}cm")

print(width * 37.7952755906)
print(height * 37.7952755906)

plot1 = sg.fromfile("npe_with_sweep.svg")
plot1 = plot1.getroot()
plot1.moveto(8, 0, scale=1.0)

fig.append([plot1])

fig.save("fig_sweep.svg")

svg = SVG("fig_sweep.svg")
svg
# Out:
# 529.1338582684
# 105.82677165368
