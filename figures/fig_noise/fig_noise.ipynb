# %%
import svgutils.transform as sg
from IPython.display import SVG

width = 14
height = 4.2
fig = sg.SVGFigure(width=f"{width}cm", height=f"{height}cm")


fig1 = sg.fromfile("heatmap_noise1_feat1_sim1000_dim5.svg")
plot1 = fig1.getroot()

plot2 = sg.fromfile("laplace_cauchy_comparison.svg")
plot2 = plot2.getroot()

plot3 = sg.fromfile("logitnormal_studentt_comparison.svg")
plot3 = plot3.getroot()

plot4 = sg.fromfile("studentt_laplace_comparison.svg")
plot4 = plot4.getroot()

plot5 = sg.fromfile("legend_only.svg")
plot5 = plot5.getroot()

# plot6 = sg.fromfile("posterior_marginals.svg")
# plot6 = plot6.getroot()

txt1 = sg.TextElement(5, 15, "a", size=15, weight="bold", font="Arial")
txt2 = sg.TextElement(200, 15, "b", size=15, weight="bold", font="Arial")
txt3 = sg.TextElement(175, 48, "C2ST", size=9, font="Arial")
plot1.moveto(-2, 35, scale=1.0)
plot2.moveto(200, 5, scale=1.0)
plot5.moveto(423, 45, scale=1.0)


fig.append([plot1, plot2, plot5])
fig.append([txt1, txt2, txt3])

fig.save("fig_noise.svg")

svg = SVG("fig_noise.svg")
svg
